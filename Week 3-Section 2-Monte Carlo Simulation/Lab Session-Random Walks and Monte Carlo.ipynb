# %% [markdown]
# # Random Walk Generation

# %% [markdown]
# ![Formula](image.png)

# %%
import numpy as np
import pandas as pd

def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=.15, steps_per_year=12, s_0=100.00):
    """
    Evolution of a stock price using a Geometric Brownian Motion Model 
    """

    dt = 1/steps_per_year
    n_steps = n_years*steps_per_year
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt) * xi
    rets = pd.DataFrame(rets)
    # convert rets to prices 
    prices = s_0 * (1+rets).cumprod()
    return prices

# %%
p = gbm(10, n_scenarios=3)

# %%
p.shape
# Out:
# (120, 3)

# %%
p.head()
# Out:
#             0           1           2
# 0   98.164442  102.323636   98.727638
# 1  103.460095  103.954609  100.965089
# 2   97.336759   96.930137  106.846328
# 3   94.999953   96.610556  105.175128
# 4   99.404547   96.756843  109.544597

# %%
p.plot()
# Out:
# <Axes: >

# %%
p = gbm(n_years=10, n_scenarios=1000)

# %%
def gbm0(n_years=10, n_scenarios=1000, mu=0.07, sigma=.15, steps_per_year=12, s_0=100.00):
    """
    Evolution of a stock price using a Geometric Brownian Motion Model 
    """

    dt = 1/steps_per_year
    n_steps = n_years*steps_per_year
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt) * xi
    rets = pd.DataFrame(rets)
    # convert rets to prices 
    prices = s_0 * (1+rets).cumprod()
    return prices

def gbm1(n_years=10, n_scenarios=1000, mu=0.07, sigma=.15, steps_per_year=12, s_0=100.00):
    """
    Evolution of a stock price using a Geometric Brownian Motion Model 
    """

    dt = 1/steps_per_year
    n_steps = n_years*steps_per_year
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=(sigma*np.sqrt(dt)),size=(n_steps, n_scenarios))
    # convert rets to prices 
    prices = s_0 * pd.DataFrame(rets_plus_1).cumprod()
    return prices

def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=.15, steps_per_year=12, s_0=100.00):
    """
    Evolution of a stock price using a Geometric Brownian Motion Model 
    """

    dt = 1/steps_per_year
    n_steps = n_years*steps_per_year
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=(sigma*np.sqrt(dt)),size=(n_steps, n_scenarios))
    # convert rets to prices 
    prices = s_0 * pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
# %timeit gbm0(n_years=5, n_scenarios=1000)
# Out:
# 1.93 ms ± 142 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit gbm1(n_years=5, n_scenarios=1000)
# Out:
# 1.59 ms ± 20.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
gbm(n_years=10, n_scenarios=20).plot(legend=False, figsize=(12,6))
# Out:
# <Axes: >

# %%
def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=.15, steps_per_year=12, s_0=100.00):
    """
    Evolution of a stock price using a Geometric Brownian Motion Model 
    """

    dt = 1/steps_per_year
    n_steps = n_years*steps_per_year
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=(sigma*np.sqrt(dt)),size=(n_steps, n_scenarios))
    rets_plus_1[0] = 1
    # convert rets to prices 
    prices = s_0 * pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
gbm(n_years=10, n_scenarios=20).plot(legend=False, figsize=(12,6))
# Out:
# <Axes: >

# %%
gbm(n_scenarios=10).head()
# Out:
#             0           1           2           3           4           5  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  103.398719  101.250486  101.214325  100.457118   92.761537   95.558715
# 2  101.454418   95.069776  100.121026  104.070947   96.826180   92.787726
# 3   99.094839   94.786508   99.334349  108.318203  101.515188   93.784270
# 4  105.374069   94.750120   89.986381  103.940610  109.258254   96.730113
#
#             6           7           8           9
# 0  100.000000  100.000000  100.000000  100.000000
# 1  101.108220  100.330573   98.770024  101.758973
# 2  104.288181   99.911346  104.790941  106.631702
# 3  100.985620   95.471657  104.928389  114.728106
# 4  107.230376   96.092478   98.650196  121.312734

# %%
import ipywidgets as widgets

# %%
def squareit(n):
    return n*n

# %%
squareit(5)
# Out:
# 25

# %%
widgets.interact(squareit, n=(0,100))
# Out:
# interactive(children=(IntSlider(value=50, description='n'), Output()), _dom_classes=('widget-interact',))
# <function __main__.squareit(n)>
