# %% [markdown]
# # Implementing Portfolio Insurance (CPPI) and Drawdown Constraints

# %%
# %load_ext autoreload
# %autoreload 2
from sys import path 
path.append('../')
import edhec_risk_kit as erk
import numpy as np
import pandas as pd

ind_return = erk.get_ind_returns()
tmi_return = erk.get_total_market_index_returns()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
risky_r = ind_return['2000': ][['Steel', 'Fin', 'Beer']]
# safe asset - have to create

# %%
risky_r.shape
# Out:
# (228, 3)

# %%
safe_r = pd.DataFrame().reindex_like(risky_r)  # get DataFrame that has the same shape as risky_r

# %%
safe_r.shape
# Out:
# (228, 3)

# %%
safe_r[:] = .03/12  # 3% risk free rate 
start = 1000
floor = 0.8  # could be amount, but usually used as a fraction

# %% [markdown]
# 1. Cushion - (Asset Value minus Floor Value)
# 2. Compute an Allocation to Safe and Risky Assets ->> m * risk_budget
# 3. Recompute the Asset Value based on the returns

# %%
def compound1(r):
    return (1+r).prod()-1

def compound2(r):
    """
    We do the same thing as in compound1(), but with different steps:
        Take the log of the returns and sum them
            (or use: np.logp1(r)
            np.expm1(r) == np.exp(r-1))
        Exponentiate that to undo the logs
            and subtract 1
    """
    return np.expm1(np.log1p(r).sum())

# %%
compound1(risky_r)
# Out:
# Steel   -0.051696
# Fin      1.773937
# Beer     3.361349
# dtype: float64

# %%
compound2(risky_r)
# Out:
# Steel   -0.051696
# Fin      1.773937
# Beer     3.361349
# dtype: float64

# %%
# %timeit compound1(risky_r)
# Out:
# 299 µs ± 12.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit compound2(risky_r)  # faster because we are looping the most efficient way
# Out:
# 275 µs ± 11.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Back to CPPI

# %%
dates = risky_r.index
n_steps = len(dates)
account_value = start
floor_value = start*floor
m = 3
account_history = pd.DataFrame().reindex_like(risky_r)
cushion_history = pd.DataFrame().reindex_like(risky_r)
risk_weight_history = pd.DataFrame().reindex_like(risky_r)

for step in range(n_steps):
    cushion = (account_value - floor_value)/account_value
    risky_weight = m*cushion
    risky_weight = np.minimum(risky_weight, 1)  # make sure weight doesn't go over 100% (you could with leverage)
    safe_weight = 1 - np.maximum(risky_weight, 0)  # don't go below 0%
    risky_alloc = account_value * risky_weight
    safe_alloc = account_value * safe_weight

    ## update the account value for this time step 
    account_value = (risky_alloc * (1+risky_r.iloc[step])) + (safe_alloc * (1+safe_r.iloc[step]))
    # save the values so I can look at the history and plot it 
    cushion_history.iloc[step] = cushion 
    risk_weight_history.iloc[step] = risky_weight
    account_history.iloc[step] = account_value

# %%
account_history.head()
# Out:
#                Steel          Fin        Beer
# 2000-01   984.380000   974.480000  987.320000
# 2000-02  1023.292876   931.167544  922.971256
# 2000-03  1047.555176   998.187296  924.835988
# 2000-04  1042.079009   973.927479  939.993701
# 2000-05  1007.137753  1001.460033  991.145489

# %%
risky_wealth = start*(1+risky_r).cumprod()
risky_wealth.plot()
# Out:
# <Axes: >

# %%
# plot both on the same chart 
ax = account_history['Beer'].plot(figsize=(12,6), legend=True)
risky_wealth['Beer'].plot(ax=ax, style='k:', legend=True)
ax.axhline(y=floor_value, color='r', linestyle='--')

# %%
risk_weight_history.plot()
# Out:
# <Axes: >

# %%
ind = 'Fin'
ax = account_history[ind].plot(figsize=(12,6), legend=True)
risky_wealth[ind].plot(ax=ax, style='k:', legend=True)
ax.axhline(y=floor_value, color='r', linestyle='--')

# %%
ind = 'Steel'
ax = account_history[ind].plot(figsize=(12,6), legend=True)
risky_wealth[ind].plot(ax=ax, style='k:', legend=True)
ax.axhline(y=floor_value, color='r', linestyle='--')

# %%
erk.summary_stats(risky_r)
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel          -0.002790        0.312368 -0.326334  4.144381
# Fin             0.055166        0.192909 -0.533218  4.995534
# Beer            0.080598        0.138925 -0.493545  4.173881
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.150139            0.208117     -0.102567     -0.758017
# Fin                   0.091224            0.132175      0.126718     -0.718465
# Beer                  0.063015            0.091442      0.354314     -0.271368

# %%
backtest_results = erk.run_cppi(risky_r)
erk.summary_stats(backtest_results['Wealth'].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# Steel          -0.005167        0.174180 -1.995143  17.110190
# Fin             0.040894        0.131678 -0.946504   6.051414
# Beer            0.075544        0.115462 -0.669250   4.760879
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.091995            0.130153     -0.196750     -0.655198
# Fin                   0.065535            0.091621      0.080352     -0.549673
# Beer                  0.052923            0.074908      0.383772     -0.259582

# %%
backtest_results = erk.run_cppi(tmi_return['2007':])
ax = backtest_results['Wealth'].plot(figsize=(12,6), legend=False)
backtest_results['Risky Wealth'].plot(ax=ax, style='k--', legend=False)
# Out:
# <Axes: >

# %%
erk.summary_stats(backtest_results['Risky Wealth'].pct_change().dropna())
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# R           0.073411        0.150463 -0.734939  4.523488
#
#    Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# R                 0.071592            0.096315      0.280618     -0.499943

# %%
erk.summary_stats(backtest_results['Wealth'].pct_change().dropna())
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# R           0.069416        0.100381 -0.588292  3.740932
#
#    Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# R                 0.045678            0.062953      0.382052     -0.229683

# %% [markdown]
# # Drawdown Constraint

# %%
backtest_results = erk.run_cppi(ind_return['2007':][['Steel', 'Fin', 'Beer']], drawdown=0.25)

# %%
ax = backtest_results['Wealth'].plot(figsize=(12,6))
backtest_results['Risky Wealth'].plot(ax=ax, style='--')
# Out:
# <Axes: >

# %%
erk.summary_stats(backtest_results['Risky Wealth'].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel          -0.039660        0.306407 -0.459951  4.782828
# Fin             0.027364        0.212204 -0.695200  4.621401
# Beer            0.111554        0.127971 -0.670797  4.650878
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.152288            0.203837     -0.221642     -0.758017
# Fin                   0.105744            0.149862     -0.012370     -0.718465
# Beer                  0.056497            0.077388      0.620132     -0.271368

# %%
erk.summary_stats(backtest_results['Wealth'].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel           0.003784        0.097073 -0.441089  5.220481
# Fin             0.041975        0.085028 -0.355163  4.153860
# Beer            0.084375        0.086263 -0.744111  4.571533
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.047371            0.066991     -0.262958     -0.248059
# Fin                   0.038342            0.054111      0.136964     -0.243626
# Beer                  0.037937            0.051189      0.613413     -0.161186
